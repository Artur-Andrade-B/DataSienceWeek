# %% [markdown]
# ## Dados de prevalencia de problemas mentais por pais

# %% [markdown]
# ### importando o dataset

# %%
import pandas as pd

data_loc = "dataset/Mental_health_Depression_disorder_Data.csv"

data = pd.read_csv(data_loc, sep=";")
# Out:
#          Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0   Afghanistan  AFG  1990       0,160559542          0,697779385
# 1   Afghanistan  AFG  1991       0,160311899          0,697960595
# 2   Afghanistan  AFG  1992       0,160134822          0,698106969
# 3   Afghanistan  AFG  1993       0,160037391          0,698256934
# 4   Afghanistan  AFG  1994       0,160022297          0,698469118
# 5   Afghanistan  AFG  1995       0,160076309          0,698694969
# 6   Afghanistan  AFG  1996       0,160248726          0,698914125
# 7   Afghanistan  AFG  1997       0,160553947          0,699126655
# 8   Afghanistan  AFG  1998       0,160930712          0,699371875
# 9   Afghanistan  AFG  1999       0,161310885          0,699674199
# 10  Afghanistan  AFG  2000       0,161621224          0,700015097
# 11  Afghanistan  AFG  2001       0,161957171           0,70049948
# 12  Afghanistan  AFG  2002       0,162414146          0,701141209
# ...

# %% [markdown]
# ### 10 primeiros dados

# %%
data.head(10)
# Out:
#         Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0  Afghanistan  AFG  1990       0,160559542          0,697779385
# 1  Afghanistan  AFG  1991       0,160311899          0,697960595
# 2  Afghanistan  AFG  1992       0,160134822          0,698106969
# 3  Afghanistan  AFG  1993       0,160037391          0,698256934
# 4  Afghanistan  AFG  1994       0,160022297          0,698469118
# 5  Afghanistan  AFG  1995       0,160076309          0,698694969
# 6  Afghanistan  AFG  1996       0,160248726          0,698914125
# 7  Afghanistan  AFG  1997       0,160553947          0,699126655
# 8  Afghanistan  AFG  1998       0,160930712          0,699371875
# 9  Afghanistan  AFG  1999       0,161310885          0,699674199
#
#   Eating disorders (%) Anxiety disorders (%) Drug use disorders (%)  \
# 0          0,101854863           4,828829705            1,677081945
# 1           0,09931279           4,829740372            1,684745731
# ...

# %% [markdown]
# ### 10 ultimo dados

# %%
data.tail(10)
# Out:
#         Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 6458  Zimbabwe  ZWE  2008       0,156553067          0,606655564
# 6459  Zimbabwe  ZWE  2009       0,155659514          0,606757793
# 6460  Zimbabwe  ZWE  2010        0,15531193          0,606896661
# 6461  Zimbabwe  ZWE  2011       0,155353954          0,607123834
# 6462  Zimbabwe  ZWE  2012         0,1554654          0,607495017
# 6463  Zimbabwe  ZWE  2013       0,155669695          0,607992596
# 6464  Zimbabwe  ZWE  2014       0,155992631            0,6086104
# 6465  Zimbabwe  ZWE  2015       0,156465117          0,609362668
# 6466  Zimbabwe  ZWE  2016       0,157110799          0,610234233
# 6467  Zimbabwe  ZWE  2017       0,157963236           0,61124239
#
#      Eating disorders (%) Anxiety disorders (%) Drug use disorders (%)  \
# 6458          0,119728424           3,083928188            0,739987247
# 6459          0,117228508            3,08351484            0,750769285
# ...

# %%
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 6463       Zimbabwe
# 6464       Zimbabwe
# 6465       Zimbabwe
# 6466       Zimbabwe
# 6467       Zimbabwe
# Name: Entity, Length: 6468, dtype: object
